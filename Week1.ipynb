# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas-berth/Google_Colab_testing/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Fundamental Python Library for data scienctist are:
# 1. pandas: python data analysis library
# 2. scikit learn: Machine learning in python
# 3. numpy and scipy: numerical and scientific computation

# %% [markdown]
# ### Import pandas and numpy packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Import the bank_marketing_training data set and name it bank_train.

# %%
# For google colab
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-a6f2baea-8f5d-4499-9c31-57032b5cf0ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a6f2baea-8f5d-4499-9c31-57032b5cf0ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bank_marketing_training to bank_marketing_training

# %%
# Entering the absolute path to the data
bank_train = pd.read_csv("bank_marketing_training")

# %%
bank_train.head() # gives the first 5 rows
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   56    housemaid  married     basic.4y       no      no   no  telephone
# 1   57     services  married  high.school  unknown      no   no  telephone
# 2   41  blue-collar  married      unknown  unknown      no   no  telephone
# 3   25     services   single  high.school       no     yes   no  telephone
# 4   29  blue-collar   single  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  days_since_previous  previous  \
# 0   may         mon  ...         1                  999         0
# 1   may         mon  ...         1                  999         0
# 2   may         mon  ...         1                  999         0
# 3   may         mon  ...         1                  999         0
# 4   may         mon  ...         1                  999         0
#
#    previous_outcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
bank_train.shape # gives the number of rows and columms
# Out:
# (26874, 21)

# %% [markdown]
# ### 2. Create a contingency table of the variables response and previous_outcome from the bank_train data set. Do not save the output from the code.

# %%
pd.crosstab(bank_train['response'], bank_train['previous_outcome'])
# Out:
# previous_outcome  failure  nonexistent  success
# response
# no                   2390        21176      320
# yes                   385         2034      569

# %% [markdown]
# ### 3. Rerun the code from the previous exercise, this time saving the output as crosstab_01.

# %%
crosstab_01 = pd.crosstab(bank_train['response'], bank_train['previous_outcome'])

# %% [markdown]
# ### 4. After saving the output in the previous exercise, display the output using the name of the saved output.

# %%
print(crosstab_01)
# Out:
# previous_outcome  failure  nonexistent  success
# response
# no                   2390        21176      320
# yes                   385         2034      569

# %% [markdown]
# ### 5. Save the contingency table under a different name. This time, use your last name and favorite number as the name;for example, larose42.

# %%
Berth_14 = crosstab_01

# %% [markdown]
# ### 6. Save the first nine records of the bank_train data set as their own data frame.

# %%
first_9 = pd.DataFrame(bank_train) 
first_9.head(9)
# Out:
#    age          job   marital    education  default housing loan    contact  \
# 0   56    housemaid   married     basic.4y       no      no   no  telephone
# 1   57     services   married  high.school  unknown      no   no  telephone
# 2   41  blue-collar   married      unknown  unknown      no   no  telephone
# 3   25     services    single  high.school       no     yes   no  telephone
# 4   29  blue-collar    single  high.school       no      no  yes  telephone
# 5   57    housemaid  divorced     basic.4y       no     yes   no  telephone
# 6   35  blue-collar   married     basic.6y       no     yes   no  telephone
# 7   39   management    single     basic.9y  unknown      no   no  telephone
# 8   30   unemployed   married  high.school       no      no   no  telephone
#
#   month day_of_week  ...  campaign  days_since_previous  previous  \
# 0   may         mon  ...         1                  999         0
# 1   may         mon  ...         1                  999         0
# ...

# %% [markdown]
# ### 7. Save the age and marital records of the bank_train data set as their own data frame.

# %%
age_marital = pd.DataFrame(bank_train['marital'], bank_train['age'])

# %% [markdown]
# ### 8. Save the first three records of the age and marital variables as their own data frame.

# %%
first_3 = age_marital.head(3)
